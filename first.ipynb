# %% [markdown]
# <a href="https://colab.research.google.com/github/svenu38/numpy-/blob/main/first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("well come to google colab")
# Out:
# well come to google colab

# %%
# !pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
arr = np.array([[1,2,3,4],[3,4,5,6]])
print(arr.ndim)
# Out:
# 2

# %%
print("")

# %% [markdown]
# numpy basic program

# %%
print("shape of the array : ",arr.shape)
print("no of dimension : ",arr.ndim)
print("size of the array : ",arr.size)
print("array is of type :" ,type(arr))
# Out:
# shape of the array :  (2, 4)
# no of dimension :  2
# size of the array :  8
# array is of type : <class 'numpy.ndarray'>
